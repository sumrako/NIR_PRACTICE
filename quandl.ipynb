# %% [markdown]
# # Quandl
#
# Здесь представлена работа с api `quandl`, который предоставляет доступ к данным биржи NASDAQ. Подробнее здесь: [документация](https://www.quandl.com/tools/api)

# %% [markdown]
# Ниже делаем импорт неоходимых библиотек и задаем персональный ключ, полученный мною при регистрации на портале `quandl`

# %%
import quandl
import matplotlib.pyplot as plt

quandl.ApiConfig.api_key = "Y1CzxdrUwA6QGpSHMHLb"

# %% [markdown]
# В следующих ячейках происходит получение данных о цене на нефть и построение графика полученного временного ряда,
# а также получение данных о цене акций Apple в виде таблицы.

# %%
plt.style.use('fivethirtyeight')
# %matplotlib inline
oil_data = quandl.get('EIA/PET_RWTC_D')
oil = oil_data.squeeze()
oil.plot(lw=2, title='WTI Crude Oil Price');

# %%
zask = quandl.get_table('ZACKS/FC', ticker='AAPL')

# %%
zask.head()
# Out:
#      m_ticker ticker comp_name comp_name_2 exchange currency_code  \
# None
# 0        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
# 1        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
# 2        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
# 3        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
# 4        AAPL   AAPL     Apple  Apple Inc.   NASDAQ           USD
#
#      per_end_date per_type per_code  per_fisc_year       ...         \
# None                                                     ...
# 0      2018-09-30        A     None           2018       ...
# 1      2018-03-31        Q     None           2018       ...
# 2      2018-06-30        Q     None           2018       ...
# 3      2018-09-30        Q     None           2018       ...
# 4      2018-12-31        Q     None           2019       ...
#
#       stock_based_compsn_qd  cash_flow_oper_activity_qd  \
# None
# 0                       NaN                         NaN
# ...
